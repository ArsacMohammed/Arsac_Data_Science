# %%
import pandas as pd

# %%
df=pd.DataFrame({'Retail_shops':('Croma','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                              'Walmart','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                             'Walmart','Big_basket','Walmart'),
                 "City":("Chennai","Kovai","Tirupati",'Hyd',"Tirupati",
                        "Chennai","Hyd","Hyd","Kovai","Agra","Pune","Agra","Chennai"),
             "Sales":(60000,50000,70000,55000,40000,30000,55000,40000,30000,70000,40000,50000,55000)})
df
# Out:
#      Retail_shops      City  Sales
# 0           Croma   Chennai  60000
# 1   Reliance_mart     Kovai  50000
# 2            RMKV  Tirupati  70000
# 3   Chennai_silks       Hyd  55000
# 4      Big_basket  Tirupati  40000
# 5         Walmart   Chennai  30000
# 6   Reliance_mart       Hyd  55000
# 7            RMKV       Hyd  40000
# 8   Chennai_silks     Kovai  30000
# 9      Big_basket      Agra  70000
# 10        Walmart      Pune  40000
# 11     Big_basket      Agra  50000
# 12        Walmart   Chennai  55000

# %%
df.groupby('Retail_shops')['Sales'].max()
# Out:
# Retail_shops
# Big_basket       70000
# Chennai_silks    55000
# Croma            60000
# RMKV             70000
# Reliance_mart    55000
# Walmart          55000
# Name: Sales, dtype: int64

# %%
df.columns
# Out:
# Index(['Retail_shops', 'City', 'Sales'], dtype='object')

# %%
col=[]
for column in df.columns:
    if column != "City":
        col.append(column)
df[col]
# this program helps in print all the column except city (own)
# Out:
#      Retail_shops  Sales
# 0           Croma  60000
# 1   Reliance_mart  50000
# 2            RMKV  70000
# 3   Chennai_silks  55000
# 4      Big_basket  40000
# 5         Walmart  30000
# 6   Reliance_mart  55000
# 7            RMKV  40000
# 8   Chennai_silks  30000
# 9      Big_basket  70000
# 10        Walmart  40000
# 11     Big_basket  50000
# 12        Walmart  55000

# %%
df.loc[:,df.columns!='City']     # [:] means the range of the row like the first digit is the starting point and the second part is for destination
# Out:
#      Retail_shops  Sales
# 0           Croma  60000
# 1   Reliance_mart  50000
# 2            RMKV  70000
# 3   Chennai_silks  55000
# 4      Big_basket  40000
# 5         Walmart  30000
# 6   Reliance_mart  55000
# 7            RMKV  40000
# 8   Chennai_silks  30000
# 9      Big_basket  70000
# 10        Walmart  40000
# 11     Big_basket  50000
# 12        Walmart  55000

# %%
df.groupby('Retail_shops')["Sales"].sum()
#this gives the sum of the sales that take place in each shops
# Out:
# Retail_shops
# Big_basket       160000
# Chennai_silks     85000
# Croma             60000
# RMKV             110000
# Reliance_mart    105000
# Walmart          125000
# Name: Sales, dtype: int64

# %%
df1=pd.DataFrame(df.groupby('Retail_shops')["Sales"].sum()) ### doubt
df1
# Out:
#                 Sales
# Retail_shops
# Big_basket     160000
# Chennai_silks   85000
# Croma           60000
# RMKV           110000
# Reliance_mart  105000
# Walmart        125000

# %%
df2=df.groupby('Retail_shops')["Sales"].sum()
df2
# Out:
# Retail_shops
# Big_basket       160000
# Chennai_silks     85000
# Croma             60000
# RMKV             110000
# Reliance_mart    105000
# Walmart          125000
# Name: Sales, dtype: int64

# %%
#Sorting the  according to the sales
df.sort_values(["City",'Sales'])  ## sort with respect to the city like within city which rank higher or lower
# Out:
#      Retail_shops      City  Sales
# 11     Big_basket      Agra  50000
# 9      Big_basket      Agra  70000
# 5         Walmart   Chennai  30000
# 12        Walmart   Chennai  55000
# 0           Croma   Chennai  60000
# 7            RMKV       Hyd  40000
# 3   Chennai_silks       Hyd  55000
# 6   Reliance_mart       Hyd  55000
# 8   Chennai_silks     Kovai  30000
# 1   Reliance_mart     Kovai  50000
# 10        Walmart      Pune  40000
# 4      Big_basket  Tirupati  40000
# 2            RMKV  Tirupati  70000

# %%
df.sort_values(['Sales','City'],ascending=False)   ## sort with respect to the sales
# Out:
#      Retail_shops      City  Sales
# 2            RMKV  Tirupati  70000
# 9      Big_basket      Agra  70000
# 0           Croma   Chennai  60000
# 3   Chennai_silks       Hyd  55000
# 6   Reliance_mart       Hyd  55000
# 12        Walmart   Chennai  55000
# 1   Reliance_mart     Kovai  50000
# 11     Big_basket      Agra  50000
# 4      Big_basket  Tirupati  40000
# 10        Walmart      Pune  40000
# 7            RMKV       Hyd  40000
# 8   Chennai_silks     Kovai  30000
# 5         Walmart   Chennai  30000

# %%
df.head()
# Out:
#     Retail_shops      City  Sales
# 0          Croma   Chennai  60000
# 1  Reliance_mart     Kovai  50000
# 2           RMKV  Tirupati  70000
# 3  Chennai_silks       Hyd  55000
# 4     Big_basket  Tirupati  40000

# %%
#11)Rank the Shops (based on Sales).Create a new column named "Rank_of_Shops".
#(do not focus on city column
#Ordinal Ranking: Assigns each element a unique integer rank without skipping ranks, but if tied values exist, the average rank is assigned to those elements
#Dense Ranking: Similar to ordinal ranking, but skips ranks when tied values exist. 
# df["rank_sales"]=-df["Sales"].rank(method="average")
df["rank_shops"]=df["Sales"].rank(method="dense")
df
#shop and citycol is not considered.
# Out:
#      Retail_shops      City  Sales  rank_sales  rank_shops
# 0           Croma   Chennai  60000         5.0         5.0
# 1   Reliance_mart     Kovai  50000         3.0         3.0
# 2            RMKV  Tirupati  70000         6.0         6.0
# 3   Chennai_silks       Hyd  55000         4.0         4.0
# 4      Big_basket  Tirupati  40000         2.0         2.0
# 5         Walmart   Chennai  30000         1.0         1.0
# 6   Reliance_mart       Hyd  55000         4.0         4.0
# 7            RMKV       Hyd  40000         2.0         2.0
# 8   Chennai_silks     Kovai  30000         1.0         1.0
# 9      Big_basket      Agra  70000         6.0         6.0
# 10        Walmart      Pune  40000         2.0         2.0
# 11     Big_basket      Agra  50000         3.0         3.0
# 12        Walmart   Chennai  55000         4.0         4.0

# %%
# df['Sales'].rank(method='dense').astype(int)  # the rank are converted into int 
df.head()
# Out:
#     Retail_shops      City  Sales  rank_sales  rank_shops
# 0          Croma   Chennai  60000         5.0         5.0
# 1  Reliance_mart     Kovai  50000         3.0         3.0
# 2           RMKV  Tirupati  70000         6.0         6.0
# 3  Chennai_silks       Hyd  55000         4.0         4.0
# 4     Big_basket  Tirupati  40000         2.0         2.0

# %%
df.sort_values(['rank_shops'],ascending=True)
# Out:
#      Retail_shops      City  Sales  rank_sales  rank_shops
# 5         Walmart   Chennai  30000         1.0         1.0
# 8   Chennai_silks     Kovai  30000         1.0         1.0
# 4      Big_basket  Tirupati  40000         2.0         2.0
# 7            RMKV       Hyd  40000         2.0         2.0
# 10        Walmart      Pune  40000         2.0         2.0
# 1   Reliance_mart     Kovai  50000         3.0         3.0
# 11     Big_basket      Agra  50000         3.0         3.0
# 3   Chennai_silks       Hyd  55000         4.0         4.0
# 6   Reliance_mart       Hyd  55000         4.0         4.0
# 12        Walmart   Chennai  55000         4.0         4.0
# 0           Croma   Chennai  60000         5.0         5.0
# 2            RMKV  Tirupati  70000         6.0         6.0
# 9      Big_basket      Agra  70000         6.0         6.0

# %%
df.loc[:,df.columns !='rank_sales']
# Out:
#      Retail_shops      City  Sales  rank_shops
# 0           Croma   Chennai  60000         5.0
# 1   Reliance_mart     Kovai  50000         3.0
# 2            RMKV  Tirupati  70000         6.0
# 3   Chennai_silks       Hyd  55000         4.0
# 4      Big_basket  Tirupati  40000         2.0
# 5         Walmart   Chennai  30000         1.0
# 6   Reliance_mart       Hyd  55000         4.0
# 7            RMKV       Hyd  40000         2.0
# 8   Chennai_silks     Kovai  30000         1.0
# 9      Big_basket      Agra  70000         6.0
# 10        Walmart      Pune  40000         2.0
# 11     Big_basket      Agra  50000         3.0
# 12        Walmart   Chennai  55000         4.0

# %%
df.sort_values(['rank_shops'],ascending=True)
# Out:
#      Retail_shops      City  Sales  rank_sales  rank_shops
# 5         Walmart   Chennai  30000         1.0         1.0
# 8   Chennai_silks     Kovai  30000         1.0         1.0
# 4      Big_basket  Tirupati  40000         2.0         2.0
# 7            RMKV       Hyd  40000         2.0         2.0
# 10        Walmart      Pune  40000         2.0         2.0
# 1   Reliance_mart     Kovai  50000         3.0         3.0
# 11     Big_basket      Agra  50000         3.0         3.0
# 3   Chennai_silks       Hyd  55000         4.0         4.0
# 6   Reliance_mart       Hyd  55000         4.0         4.0
# 12        Walmart   Chennai  55000         4.0         4.0
# 0           Croma   Chennai  60000         5.0         5.0
# 2            RMKV  Tirupati  70000         6.0         6.0
# 9      Big_basket      Agra  70000         6.0         6.0

# %%
df_g1=pd.DataFrame(df.groupby("Retail_shops")["Sales"].sum())
df_g1
# Out:
#                 Sales
# Retail_shops
# Big_basket     160000
# Chennai_silks   85000
# Croma           60000
# RMKV           110000
# Reliance_mart  105000
# Walmart        125000

# %%
df_g1["rank_of_shops"]=df_g1["Sales"].rank(method="dense",ascending=False)
df_g1
# Out:
#                 Sales  rank_of_shops
# Retail_shops
# Big_basket     160000            1.0
# Chennai_silks   85000            5.0
# Croma           60000            6.0
# RMKV           110000            3.0
# Reliance_mart  105000            4.0
# Walmart        125000            2.0

# %%
df_g1.sort_values(["rank_of_shops"])
# Out:
#                 Sales  rank_of_shops
# Retail_shops
# Big_basket     160000            1.0
# Walmart        125000            2.0
# RMKV           110000            3.0
# Reliance_mart  105000            4.0
# Chennai_silks   85000            5.0
# Croma           60000            6.0

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Retail_shops':('Croma','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                              'Walmart','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                             'Walmart','Big_basket','Walmart'),
                 "City":("Chennai","Kovai","Tirupati",'Hyd',"Tirupati",
                        "Chennai","Hyd","Hyd","Kovai","Agra","Pune","Agra","Chennai"),
             "Sales":(60000,50000,70000,55000,40000,30000,55000,40000,30000,70000,40000,50000,55000)})
df
# Out:
#      Retail_shops      City  Sales
# 0           Croma   Chennai  60000
# 1   Reliance_mart     Kovai  50000
# 2            RMKV  Tirupati  70000
# 3   Chennai_silks       Hyd  55000
# 4      Big_basket  Tirupati  40000
# 5         Walmart   Chennai  30000
# 6   Reliance_mart       Hyd  55000
# 7            RMKV       Hyd  40000
# 8   Chennai_silks     Kovai  30000
# 9      Big_basket      Agra  70000
# 10        Walmart      Pune  40000
# 11     Big_basket      Agra  50000
# 12        Walmart   Chennai  55000

# %%
df.groupby(['Retail_shops'])["Sales"].mean()
# Out:
# Retail_shops
# Big_basket       53333.333333
# Chennai_silks    42500.000000
# Croma            60000.000000
# RMKV             55000.000000
# Reliance_mart    52500.000000
# Walmart          41666.666667
# Name: Sales, dtype: float64

# %%
import pandas as pd

data = {
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Sales': [100, 150, 120, 200]
}

df = pd.DataFrame(data)

pivot_df = df.pivot(index='Date', columns='Category', values='Sales')

# %%
pivot_df
# Out:
# Category      A    B
# Date
# 2023-01-01  100  150
# 2023-01-02  120  200

# %%
df
# Out:
#          Date Category  Sales
# 0  2023-01-01        A    100
# 1  2023-01-01        B    150
# 2  2023-01-02        A    120
# 3  2023-01-02        B    200

# %%
df=pd.DataFrame({'Retail_shops':('Croma','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                              'Walmart','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                             'Walmart','Big_basket','Walmart'),
                 "City":("Chennai","Kovai","Tirupati",'Hyd',"Tirupati",
                        "Chennai","Hyd","Hyd","Kovai","Agra","Pune","Agra","Chennai"),
             "Sales":(60000,50000,70000,55000,40000,30000,55000,40000,30000,70000,40000,50000,55000)})
df
# Out:
#      Retail_shops      City  Sales
# 0           Croma   Chennai  60000
# 1   Reliance_mart     Kovai  50000
# 2            RMKV  Tirupati  70000
# 3   Chennai_silks       Hyd  55000
# 4      Big_basket  Tirupati  40000
# 5         Walmart   Chennai  30000
# 6   Reliance_mart       Hyd  55000
# 7            RMKV       Hyd  40000
# 8   Chennai_silks     Kovai  30000
# 9      Big_basket      Agra  70000
# 10        Walmart      Pune  40000
# 11     Big_basket      Agra  50000
# 12        Walmart   Chennai  55000

# %%
pd.pivot_table(df,index='Retail_shops',values='Sales',aggfunc='mean')
# rather than groupby (provides the )
# Out:
#                       Sales
# Retail_shops
# Big_basket     53333.333333
# Chennai_silks  42500.000000
# Croma          60000.000000
# RMKV           55000.000000
# Reliance_mart  52500.000000
# Walmart        41666.666667

# %%
# min in sales
pd.pivot_table(df,index='Retail_shops',values='Sales',aggfunc='min')
# Out:
#                Sales
# Retail_shops
# Big_basket     40000
# Chennai_silks  30000
# Croma          60000
# RMKV           40000
# Reliance_mart  50000
# Walmart        30000

# %%
#16)Compute the average sales for each shop in every city.
df_p=pd.pivot_table(df,index='Retail_shops',columns="City",values="Sales",aggfunc='mean')
df_p
#or df_cs=pd.pivot_table(df,index='Retail_shops',columns='City',values='Sales',aggfunc=np.mean)
# Out:
# City              Agra  Chennai      Hyd    Kovai     Pune  Tirupati
# Retail_shops
# Big_basket     60000.0      NaN      NaN      NaN      NaN   40000.0
# Chennai_silks      NaN      NaN  55000.0  30000.0      NaN       NaN
# Croma              NaN  60000.0      NaN      NaN      NaN       NaN
# RMKV               NaN      NaN  40000.0      NaN      NaN   70000.0
# Reliance_mart      NaN      NaN  55000.0  50000.0      NaN       NaN
# Walmart            NaN  42500.0      NaN      NaN  40000.0       NaN

# %%
df_p.loc[:,['Hyd']]
# Out:
# City               Hyd
# Retail_shops
# Big_basket         NaN
# Chennai_silks  55000.0
# Croma              NaN
# RMKV           40000.0
# Reliance_mart  55000.0
# Walmart            NaN

# %%
# df_p.Agra.loc[['Croma'],:]
# df_p.loc[['Big_basket'],["Agra"]]
df_p.loc[:,['Agra']]
# Out:
# City              Agra
# Retail_shops
# Big_basket     60000.0
# Chennai_silks      NaN
# Croma              NaN
# RMKV               NaN
# Reliance_mart      NaN
# Walmart            NaN

# %%
#17. Compute the minimum sales for every shop in every city
df=pd.DataFrame({'Retail_shops':('Croma','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                              'Walmart','Reliance_mart','RMKV','Chennai_silks','Big_basket',
                             'Walmart','Big_basket','Walmart'),
                 "City":("Chennai","Kovai","Tirupati",'Hyd',"Tirupati",
                        "Chennai","Hyd","Hyd","Kovai","Agra","Pune","Agra","Chennai"),
             "Sales":(60000,50000,70000,55000,40000,30000,55000,40000,30000,70000,40000,50000,55000)})
df
# Out:
#      Retail_shops      City  Sales
# 0           Croma   Chennai  60000
# 1   Reliance_mart     Kovai  50000
# 2            RMKV  Tirupati  70000
# 3   Chennai_silks       Hyd  55000
# 4      Big_basket  Tirupati  40000
# 5         Walmart   Chennai  30000
# 6   Reliance_mart       Hyd  55000
# 7            RMKV       Hyd  40000
# 8   Chennai_silks     Kovai  30000
# 9      Big_basket      Agra  70000
# 10        Walmart      Pune  40000
# 11     Big_basket      Agra  50000
# 12        Walmart   Chennai  55000

# %%
pd.pivot_table(df,index="Retail_shops",columns="City",values="Sales",aggfunc='min')
# Out:
# City              Agra  Chennai      Hyd    Kovai     Pune  Tirupati
# Retail_shops
# Big_basket     50000.0      NaN      NaN      NaN      NaN   40000.0
# Chennai_silks      NaN      NaN  55000.0  30000.0      NaN       NaN
# Croma              NaN  60000.0      NaN      NaN      NaN       NaN
# RMKV               NaN      NaN  40000.0      NaN      NaN   70000.0
# Reliance_mart      NaN      NaN  55000.0  50000.0      NaN       NaN
# Walmart            NaN  30000.0      NaN      NaN  40000.0       NaN

# %%
df.columns
# Out:
# Index(['Retail_shops', 'City', 'Sales'], dtype='object')

# %%
df["Retail_shops"].tolist() #this is how to get the row names
# Out:
# ['Croma',
#  'Reliance_mart',
#  'RMKV',
#  'Chennai_silks',
#  'Big_basket',
#  'Walmart',
#  'Reliance_mart',
#  'RMKV',
#  'Chennai_silks',
#  'Big_basket',
#  'Walmart',
#  'Big_basket',
#  'Walmart']

# %%
#to get the indec 
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %% [markdown]
# ### Next

# %%
df=pd.DataFrame([
    ['Samsung galaxy y','3_Roses',1000],
                    ['Smart tv M2023','Horlicks',1500],
              ['Washing machine M2022','Surf excel',2000]],
                   index=['a','b','c'],
                   columns=['Samsung','Hindustan_Unilever','Units_sold'])
df.head()
# Out:
#                  Samsung Hindustan_Unilever  Units_sold
# a       Samsung galaxy y            3_Roses        1000
# b         Smart tv M2023           Horlicks        1500
# c  Washing machine M2022         Surf excel        2000

# %%
#type(df.iloc[0,0])   to identify the type

# %%
import numpy as np

# %%
#series = pd.Series(data, index=index) -eg
sp=pd.Series(data=np.arange(5))
for s in sp:
    print(s)
    
# np.arange(5),np.arange(3,10,2)  lke range at for loop in python
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
df.loc[:,['Samsung']] # to get all rows in the column
# Out:
#                  Samsung
# a       Samsung galaxy y
# b         Smart tv M2023
# c  Washing machine M2022

# %%
df.loc[['a'],:]  # to get all column for a particular row
# Out:
#             Samsung Hindustan_Unilever  Units_sold
# a  Samsung galaxy y            3_Roses        1000

# %%
df.loc[['a'],['Samsung']]
# Out:
#             Samsung
# a  Samsung galaxy y

# %%
len(df.loc[['a'],['Samsung']].Samsung[0][-8:-1:2])  # imp
# Out:
# 4

# %%
df.loc[['a'],['Samsung']].Samsung[0] # imp
# Out:
# 'Samsung galaxy y'

# %%
df.loc[df['Units_sold']>1500]   # to find row  which satisfies the  conditions and if i assign value the entire  row will change
# Out:
#                  Samsung Hindustan_Unilever  Units_sold
# c  Washing machine M2022         Surf excel        2000

# %%
df.loc['a':'c',['Samsung']]   # use the first column as index
# Out:
#                  Samsung
# a       Samsung galaxy y
# b         Smart tv M2023
# c  Washing machine M2022

# %%
df.iloc[0:2,0][1][-5:]
# Out:
# 'M2023'

# %%
df
# Out:
#                  Samsung Hindustan_Unilever  Units_sold
# a       Samsung galaxy y            3_Roses        1000
# b         Smart tv M2023           Horlicks        1500
# c  Washing machine M2022         Surf excel        2000

# %%
df.loc[df["Samsung"]=='Smart tv M2023',["Samsung"]]='Samsung tablet M2023'
df
# Out:
#                  Samsung Hindustan_Unilever Units_sold
# a       Samsung galaxy y            3_Roses       1000
# b   Samsung tablet M2023           Horlicks       1500
# c  Washing machine M2022         Surf excel       2000

# %%
df.loc[df['Samsung']=='Smart tv M2023',:]='Samsung tablet M2023'   ### doubt
df
# Out:
#                  Samsung Hindustan_Unilever Units_sold
# a       Samsung galaxy y            3_Roses       1000
# b   Samsung tablet M2023           Horlicks       1500
# c  Washing machine M2022         Surf excel       2000

# %%
df.loc['b',['Samsung']]="Smart Tv"

# %%
df
# Out:
#                  Samsung Hindustan_Unilever Units_sold
# a       Samsung galaxy y            3_Roses       1000
# b               Smart Tv           Horlicks       1500
# c  Washing machine M2022         Surf excel       2000

# %%
#19)Create a df with series data and assign column names.
s1=pd.Series(["ram","byju","shethal","smith","bhavana"])
s2=pd.Series(["1","1","0","1","0"])
s3=pd.Series(['Private','Govt.','Private','Private','Govt.'])

# %%
s1,s2,s3
# Out:
# (0        ram
#  1       byju
#  2    shethal
#  3      smith
#  4    bhavana
#  dtype: object,
#  0    1
#  1    1
#  2    0
#  3    1
#  4    0
#  dtype: object,
#  0    Private
#  1      Govt.
#  2    Private
#  3    Private
#  4      Govt.
#  dtype: object)

# %%
# s2.index+=1
# s2.index.tolist()

# %%
# to assign the column names 
df1=s1.to_frame('Name')
df2=s2.to_frame("Gender")
df3=s3.to_frame('Job')
df4=pd.concat([df1,df2,df3],axis=1)

# %%
df4
# Out:
#       Name Gender      Job
# 0      ram      1  Private
# 1     byju      1    Govt.
# 2  shethal      0  Private
# 3    smith      1  Private
# 4  bhavana      0    Govt.

# %%
# df4.Gender.map({1:"Male",0:"Female"})   # doubt

# %%
df4
# Out:
#       Name Gender      Job
# 0      ram      1  Private
# 1     byju      1    Govt.
# 2  shethal      0  Private
# 3    smith      1  Private
# 4  bhavana      0    Govt.

# %%
#Q)Replace 1's with male and all 0's with female in the gender feature.
df4["Gender"].replace(to_replace={"1":"Male","0":"Female"},inplace=True)

# %%
df4
# Out:
#       Name  Gender      Job
# 0      ram    Male  Private
# 1     byju    Male    Govt.
# 2  shethal  Female  Private
# 3    smith    Male  Private
# 4  bhavana  Female    Govt.

# %%
df4.loc[df4['Name']=='byju',['Job']] ['Job'][1]
# Out:
# 'Govt.'

# %%
df4
# Out:
#       Name  Gender      Job
# 0      ram    Male  Private
# 1     byju    Male    Govt.
# 2  shethal  Female  Private
# 3    smith    Male  Private
# 4  bhavana  Female    Govt.

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.to_csv("tips.csv")

# %%
#Q1)Display the gender of the customer who paid maximum  total bill.
df.loc[df["total_bill"]==df["total_bill"].max()]#["sex"]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
max(df.index.tolist()) #find the last index
# Out:
# 243

# %%
# a=df.loc[df.time=='Dinner']
# tot=0
# for i in a:
#     tot+=1
# print(tot)
# print(a)
# Out:
# 7
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.groupby(df["sex"]).count()  # using groupby
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Male           157  157     157  157   157   157
# Female          87   87      87   87    87    87

# %%
df["sex"].value_counts()   #using value counts
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.isnull().sum()   # shows how many null value present in each column
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df["sex"].value_counts(),labels=["Male","Female"],colors=["red","blue"])
plt.show()

# %%
sns.countplot
# Out:
# <function seaborn.categorical.countplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)>

# %%
#3)Calculate the female customers who smoke and paid tips more than 5 units.

# %%
df.loc[(df["sex"]=="Female")& (df["smoker"]=="Yes")& (df.tip>=5)]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 73        25.28  5.0  Female    Yes   Sat  Dinner     2
# 197       43.11  5.0  Female    Yes  Thur   Lunch     4
# 214       28.17  6.5  Female    Yes   Sat  Dinner     3

# %%
#Q4)At what time, did most of the customers come to the restaurant.plot it in a graph.
#size,time col
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
plt.pie(df["time"].value_counts(),labels=['Dinner','Lunch'],colors=["#abcdef","red"],autopct="%.2f%%")
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.loc[df['time']=='Dinner']["size"].sum()  # to find the total customer in the dinner time
# Out:
# 463

# %%
df.loc[df["time"]=='Lunch']["size"].sum()     # to find the total customer in the lunch time
# Out:
# 164

# %%
# seaborn graph
sns.countplot(x='time',data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# plt.pie(x=prices,labels=fruits,colors=['red','orange','green','yellow'],autopct='%1.2f%%')

# %%
# another class

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\mm\Arsac_Data_Science\Emp_reimb.csv")

# %%
df
# Out:
#        Year Type_of_yr  Emp_ID     Income  Other_Income  Overtime  \
# 0      2015  Financial   42865   92288.22        267.45    270.45
# 1      2015   Calendar   28253    1466.38          0.00    350.23
# 2      2018  Financial   30664   76536.95      10855.94  13586.72
# 3      2018  Financial   19482   45659.88       1625.37      3.00
# 4      2017  Financial    7183   41832.00          0.00      6.00
# ...     ...        ...     ...        ...           ...       ...
# 49789  2016  Financial    1640  100222.50        600.00  17171.13
# 49790  2018  Financial   35479    1787.41          0.00      8.00
# 49791  2016  Financial   42178   36552.83          0.00      5.00
# 49792  2016  Financial   10992   46995.30      10943.14      5.00
# 49793  2018  Financial   29083   69268.81       1648.09      5.00
#
#        Total_Income  Health_Insurance  Retirement  Other_Benefits  \
# 0          92826.12          12500.56    20703.20         7605.75
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Type_of_yr', 'Emp_ID', 'Income', 'Other_Income', 'Overtime',
#        'Total_Income', 'Health_Insurance', 'Retirement', 'Other_Benefits',
#        'Total_Benefits', 'Total_Reimbursement'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Year Type_of_yr  Emp_ID     Income  Other_Income  Overtime  Total_Income  \
# 0  2015  Financial   42865   92288.22        267.45    270.45      92826.12
# 1  2015   Calendar   28253    1466.38          0.00    350.23       1816.61
# 2  2018  Financial   30664   76536.95      10855.94  13586.72     100979.61
# 3  2018  Financial   19482   45659.88       1625.37      3.00      47288.25
# 4  2017  Financial    7183   41832.00          0.00      6.00      41838.00
# 5  2017   Calendar   50436   74132.00       1443.42      4.00      75579.42
# 6  2018  Financial   35659  101535.10          0.00      8.00     101543.10
# 7  2018   Calendar   38092  109163.02       4366.49      4.00     113533.51
# 8  2015  Financial   27247   66232.32       2069.97   6810.80      75113.09
# 9  2018  Financial   46326   53979.94         25.00   7207.89      61212.83
#
#    Health_Insurance  Retirement  Other_Benefits  Total_Benefits  \
# 0          12500.56    20703.20         7605.75        40809.51
# ...

# %%
df.shape
# Out:
# (49794, 12)

# %%
#Q1)Display the records of employees who's age is more than 50 and smoke.
#Q2)Calculate the percentage of female employees who do not consume alcohol daily.
df.loc[df['sex']=="Male"]
